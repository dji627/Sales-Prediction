# %%
#Import libraries
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../ML-Custom-Functions')
import os
from CustomFunctions import *
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)

# %%
#import datasets
train = pd.read_csv('store-sales-time-series-forecasting/train.csv')
test = pd.read_csv('store-sales-time-series-forecasting/test.csv')
holidays_events = pd.read_csv('store-sales-time-series-forecasting/holidays_events.csv')
oil = pd.read_csv('store-sales-time-series-forecasting/oil.csv')
stores = pd.read_csv('store-sales-time-series-forecasting/stores.csv')
transactions = pd.read_csv('store-sales-time-series-forecasting/transactions.csv')

dataSetList = [train,test,holidays_events,oil,stores,transactions]

# %%
showDataInfo(train,features_to_display = 'family', display_data_frame = True, show_data_details=True,show_graph=True,classification_or_regression='regression',output='sales')
# Out:
# features selected: ['family']
# <class 'list'>
#        family
# 0  AUTOMOTIVE
# 1   BABY CARE
# 2      BEAUTY
# 3   BEVERAGES
# 4       BOOKS
# Total number of rows: 3000888
# ==================================================
# family    object
# dtype: object
# ==================================================
# Feature: family---------Type: object
# family(33 unique values:)
# AUTOMOTIVE: 90936
# HOME APPLIANCES: 90936
# SCHOOL AND OFFICE SUPPLIES: 90936
# PRODUCE: 90936
# PREPARED FOODS: 90936
# POULTRY: 90936
# PLAYERS AND ELECTRONICS: 90936
# PET SUPPLIES: 90936
# PERSONAL CARE: 90936
# MEATS: 90936
# MAGAZINES: 90936
# ...more than 10 unique value detected, consider feature type conversion
# features selected: ['family']
# <class 'list'>
# ==================================================

# %%
for table in dataSetList:
    showDataInfo(table,features_to_display = 'All', display_data_frame = True, show_data_details=True)
# Out:
# features selected: ['id', 'date', 'store_nbr', 'family', 'sales', 'onpromotion']
# <class 'list'>
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0
# Total number of rows: 3000888
# ==================================================
# id               int64
# date            object
# store_nbr        int64
# family          object
# sales          float64
# onpromotion      int64
# dtype: object
# ==================================================
# Feature: id---------Type: int64
# id: Max:3000887, Min:0, Median:1500443.500 Mean:1500443.500, std:866281.892,Skewness:-0.000
# mode: 3000888 modes in total
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# Feature: date---------Type: object
# date(1684 unique values:)
# 2013-01-01: 1782
# 2016-01-15: 1782
# 2016-02-08: 1782
# 2016-02-07: 1782
# 2016-02-06: 1782
# 2016-02-05: 1782
# 2016-02-04: 1782
# 2016-02-03: 1782
# 2016-02-02: 1782
# 2016-02-01: 1782
# 2016-01-31: 1782
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: store_nbr---------Type: int64
# store_nbr: Max:54, Min:1, Median:27.500 Mean:27.500, std:15.586,Skewness:0.000
# mode: 54 modes in total
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: store_nbr, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# Feature: family---------Type: object
# family(33 unique values:)
# AUTOMOTIVE: 90936
# HOME APPLIANCES: 90936
# SCHOOL AND OFFICE SUPPLIES: 90936
# PRODUCE: 90936
# PREPARED FOODS: 90936
# POULTRY: 90936
# PLAYERS AND ELECTRONICS: 90936
# PET SUPPLIES: 90936
# PERSONAL CARE: 90936
# MEATS: 90936
# MAGAZINES: 90936
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: sales---------Type: float64
# sales: Max:124717.0, Min:0.0, Median:11.000 Mean:357.776, std:1101.998,Skewness:7.359
# mode: 1 modes in total
# 0    0.0
# Name: sales, dtype: float64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# Feature: onpromotion---------Type: int64
# onpromotion: Max:741, Min:0, Median:0.000 Mean:2.603, std:12.219,Skewness:11.167
# mode: 1 modes in total
# 0    0
# Name: onpromotion, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# features selected: ['id', 'date', 'store_nbr', 'family', 'onpromotion']
# <class 'list'>
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0
# Total number of rows: 28512
# ==================================================
# id              int64
# date           object
# store_nbr       int64
# family         object
# onpromotion     int64
# dtype: object
# ==================================================
# Feature: id---------Type: int64
# id: Max:3029399, Min:3000888, Median:3015143.500 Mean:3015143.500, std:8230.850,Skewness:0.000
# mode: 28512 modes in total
# 0    3000888
# 1    3000889
# 2    3000890
# 3    3000891
# 4    3000892
# Name: id, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# Feature: date---------Type: object
# date(16 unique values:)
# 2017-08-16: 1782
# 2017-08-17: 1782
# 2017-08-18: 1782
# 2017-08-19: 1782
# 2017-08-20: 1782
# 2017-08-21: 1782
# 2017-08-22: 1782
# 2017-08-23: 1782
# 2017-08-24: 1782
# 2017-08-25: 1782
# 2017-08-26: 1782
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: store_nbr---------Type: int64
# store_nbr: Max:54, Min:1, Median:27.500 Mean:27.500, std:15.586,Skewness:0.000
# mode: 54 modes in total
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: store_nbr, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# Feature: family---------Type: object
# family(33 unique values:)
# AUTOMOTIVE: 864
# HOME APPLIANCES: 864
# SCHOOL AND OFFICE SUPPLIES: 864
# PRODUCE: 864
# PREPARED FOODS: 864
# POULTRY: 864
# PLAYERS AND ELECTRONICS: 864
# PET SUPPLIES: 864
# PERSONAL CARE: 864
# MEATS: 864
# MAGAZINES: 864
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: onpromotion---------Type: int64
# onpromotion: Max:646, Min:0, Median:0.000 Mean:6.965, std:20.684,Skewness:8.496
# mode: 1 modes in total
# 0    0
# Name: onpromotion, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# features selected: ['date', 'type', 'locale', 'locale_name', 'description', 'transferred']
# <class 'list'>
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# Total number of rows: 350
# ==================================================
# date           object
# type           object
# locale         object
# locale_name    object
# description    object
# transferred      bool
# dtype: object
# ==================================================
# Feature: date---------Type: object
# date(312 unique values:)
# 2014-06-25: 4
# 2017-06-25: 3
# 2016-06-25: 3
# 2015-06-25: 3
# 2013-06-25: 3
# 2012-06-25: 3
# 2014-12-26: 2
# 2015-12-22: 2
# 2012-12-22: 2
# 2012-12-24: 2
# 2017-07-03: 2
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: type---------Type: object
# type(6 unique values:)
# Holiday: 221
# Event: 56
# Additional: 51
# Transfer: 12
# Bridge: 5
# Work Day: 5
# ==================================================
# Feature: locale---------Type: object
# locale(3 unique values:)
# National: 174
# Local: 152
# Regional: 24
# ==================================================
# Feature: locale_name---------Type: object
# locale_name(24 unique values:)
# Ecuador: 174
# Quito: 13
# Riobamba: 12
# Guaranda: 12
# Latacunga: 12
# Ambato: 12
# Guayaquil: 11
# Cuenca: 7
# Ibarra: 7
# Salinas: 6
# Loja: 6
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: description---------Type: object
# description(103 unique values:)
# Carnaval: 10
# Fundacion de Cuenca: 7
# Fundacion de Ibarra: 7
# Fundacion de Quito: 6
# Provincializacion de Santo Domingo: 6
# Provincializacion Santa Elena: 6
# Independencia de Guaranda: 6
# Independencia de Latacunga: 6
# Independencia de Ambato: 6
# Fundacion de Quito-1: 6
# Fundacion de Manta: 6
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: transferred---------Type: bool
# 2 unique values:)
# ==============================
# False    338
# True      12
# Name: transferred, dtype: int64
# ==================================================
# features selected: ['date', 'dcoilwtico']
# <class 'list'>
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# Total number of rows: 1218
# ==================================================
# date           object
# dcoilwtico    float64
# dtype: object
# ==================================================
# Feature: date---------Type: object
# date(1218 unique values:)
# 2013-01-01: 1
# 2016-02-08: 1
# 2016-02-17: 1
# 2016-02-16: 1
# 2016-02-15: 1
# 2016-02-12: 1
# 2016-02-11: 1
# 2016-02-10: 1
# 2016-02-09: 1
# 2016-02-05: 1
# 2016-07-01: 1
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: dcoilwtico---------Type: float64
# dcoilwtico: contains 43 out of 1218 missing values (0.035%, needs handling
#
# dcoilwtico: Max:110.62, Min:26.19, Median:53.190 Mean:67.714, std:25.630,Skewness:0.322
# mode: 6 modes in total
# 0    46.02
# 1    47.65
# 2    47.72
# 3    60.01
# 4    93.12
# Name: dcoilwtico, dtype: float64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# features selected: ['store_nbr', 'city', 'state', 'type', 'cluster']
# <class 'list'>
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# Total number of rows: 54
# ==================================================
# store_nbr     int64
# city         object
# state        object
# type         object
# cluster       int64
# dtype: object
# ==================================================
# Feature: store_nbr---------Type: int64
# store_nbr: Max:54, Min:1, Median:27.500 Mean:27.500, std:15.732,Skewness:0.000
# mode: 54 modes in total
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: store_nbr, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# Feature: city---------Type: object
# city(22 unique values:)
# Quito: 18
# Guayaquil: 8
# Cuenca: 3
# Santo Domingo: 3
# Manta: 2
# Latacunga: 2
# Machala: 2
# Ambato: 2
# Quevedo: 1
# Esmeraldas: 1
# Loja: 1
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: state---------Type: object
# state(16 unique values:)
# Pichincha: 19
# Guayas: 11
# Santo Domingo de los Tsachilas: 3
# Azuay: 3
# Manabi: 3
# Cotopaxi: 2
# Tungurahua: 2
# Los Rios: 2
# El Oro: 2
# Chimborazo: 1
# Imbabura: 1
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: type---------Type: object
# type(5 unique values:)
# D: 18
# C: 15
# A: 9
# B: 8
# E: 4
# ==================================================
# Feature: cluster---------Type: int64
# cluster: Max:17, Min:1, Median:8.500 Mean:8.481, std:4.693,Skewness:0.041
# mode: 1 modes in total
# 0    3
# Name: cluster, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# features selected: ['date', 'store_nbr', 'transactions']
# <class 'list'>
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# Total number of rows: 83488
# ==================================================
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object
# ==================================================
# Feature: date---------Type: object
# date(1682 unique values:)
# 2017-08-15: 54
# 2017-06-02: 54
# 2017-05-21: 54
# 2017-05-22: 54
# 2017-05-23: 54
# 2017-05-24: 54
# 2017-05-25: 54
# 2017-05-26: 54
# 2017-05-27: 54
# 2017-05-28: 54
# 2017-05-29: 54
# ...more than 10 unique value detected, consider feature type conversion
# ==================================================
# Feature: store_nbr---------Type: int64
# store_nbr: Max:54, Min:1, Median:27.000 Mean:26.939, std:15.608,Skewness:0.003
# mode: 7 modes in total
# 0    26
# 1    31
# 2    33
# 3    34
# 4    37
# Name: store_nbr, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================
# Feature: transactions---------Type: int64
# transactions: Max:8359, Min:5, Median:1393.000 Mean:1694.602, std:963.287,Skewness:1.518
# mode: 1 modes in total
# 0    1207
# Name: transactions, dtype: int64
# (-0.5 < skewness < 0.5) -> fairly symmetrical
# (-1 < skewness < -0.5) or (0.5 < skewness < 1) -> moderately skewed
# (skewness < -1) or ( 1 < skewness) -> highly skewed
# ==================================================

# %% [markdown]
# # Merging Tables

# %%
trainDf = train.merge(holidays_events,how='left',on='date')
trainDf

# %%
trainDf1 = trainDf.merge(oil,how='left',on='date')
trainDf1

# %%
# renaming the "type" column of stores to "store_type"
stores = stores.rename(columns={"type":"store_type"})

# %%
trainDf2 = trainDf1.merge(stores, how='left',on='store_nbr')
trainDf2

# %%
trainDf3 = trainDf2.merge(transactions,how='left',on=['date','store_nbr'])
trainDf3

# %% [raw]
# showDataInfo(trainDf3,features_to_display = 'All',display_data_frame = True,show_data_details=True,show_graph=True,classification_or_regression='regression',output='sales')

# %%
trainDf4=preprocessing(trainDf3,preprocess_type='dataTypeConvert',feature_selected='transferred',convert_to='bool')

# %%
category_features=['family','type','locale','locale_name','description','city','state','store_type']
trainDf5=preprocessing(trainDf4,preprocess_type='dataTypeConvert',feature_selected=category_features,convert_to='category')

# %%
trainDf6=preprocessing(trainDf5,preprocess_type='dataTypeConvert',feature_selected='date',convert_to='datetime')

# %%
showDataInfo(trainDf6,features_to_display = 'All',display_data_frame = True,show_data_details=True,show_graph=True,classification_or_regression='regression',output='sales',set_yscale='log')

# %%
showDataInfo(holidays_events,features_to_display='All', display_data_frame=True,show_data_details=True)

# %%
holidays_events

# %% [markdown]
# # Missing Value handling

# %% [markdown]
# #####
